# %%
import yfinance as yf
import datetime as d
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
s = d.datetime(2025,1,1)
e = d.datetime(2026,2,7)

# %%
info = yf.download('INFY.NS',start = s,end = e)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
info.columns = info.columns.get_level_values(0)
info = info.reset_index()
info['Stock'] = 'Infosys'

# %%
info

# %%
mah = yf.download('M&M.NS',start = s,end = e)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
mah.columns = mah.columns.get_level_values(0)
mah = mah.reset_index()
mah['Stock'] = 'Mahindra & Mahindra Ltd'

# %%
mah
# Out:
# Price       Date        Close         High          Low         Open   Volume  \
# 0     2025-01-01  3057.436279  3062.346779  2971.328032  2983.133334  1686613
# 1     2025-01-02  3185.507568  3202.372078  3060.462141  3075.292941  4298090
# 2     2025-01-03  3165.121338  3211.250732  3150.389596  3189.376423  2257218
# 3     2025-01-06  3080.947510  3209.217037  3065.471987  3184.019572  2657204
# 4     2025-01-07  3084.072510  3106.343534  3057.188400  3085.213247  1978328
# ..           ...          ...          ...          ...          ...      ...
# 270   2026-02-02  3463.199951  3472.100098  3343.699951  3355.000000  2950641
# 271   2026-02-03  3527.899902  3643.800049  3513.000000  3638.000000  5492214
# 272   2026-02-04  3574.000000  3620.000000  3519.100098  3549.000000  2395062
# 273   2026-02-05  3572.000000  3598.800049  3528.100098  3592.000000  1251428
# 274   2026-02-06  3578.000000  3590.000000  3530.600098  3577.000000  1462031
#
# Price                    Stock
# ...

# %%
sbi = yf.download('SBIN.NS',start = s,end = e)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
sbi.columns = sbi.columns.get_level_values(0)
sbi = sbi.reset_index()
sbi['Stock'] = 'State Bank of India'

# %%
sbi
# Out:
# Price       Date        Close         High          Low         Open  \
# 0     2025-01-01   777.586426   782.929158   773.959246   779.890144
# 1     2025-01-02   785.428955   786.605346   771.508460   779.350986
# 2     2025-01-03   777.782471   793.565529   776.557076   785.428921
# 3     2025-01-06   761.117126   781.899771   757.931100   781.703756
# 4     2025-01-07   763.420837   768.420423   759.597582   764.499161
# ..           ...          ...          ...          ...          ...
# 270   2026-02-02  1028.699951  1031.300049   990.000000  1019.900024
# 271   2026-02-03  1064.199951  1089.800049  1040.300049  1087.000000
# 272   2026-02-04  1068.199951  1073.900024  1056.300049  1064.199951
# 273   2026-02-05  1073.500000  1081.000000  1067.500000  1068.199951
# 274   2026-02-06  1066.400024  1073.599976  1051.000000  1070.000000
#
# Price    Volume                Stock
# 0       7273098  State Bank of India
# 1      11398319  State Bank of India
# ...

# %%
wipro = yf.download('WIPRO.NS',start = s,end = e)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
wipro.columns = wipro.columns.get_level_values(0)
wipro = wipro.reset_index()
wipro['Stock'] = 'Wipro'

# %%
wipro
# Out:
# Price       Date       Close        High         Low        Open    Volume  \
# 0     2025-01-01  281.501404  284.360493  280.235936  281.220195   7878201
# 1     2025-01-02  284.782288  285.391621  278.548579  279.345376   8800435
# 2     2025-01-03  276.017639  284.782313  275.595797  284.313612  12535720
# 3     2025-01-06  275.876984  279.157886  272.361731  276.533176   9173687
# 4     2025-01-07  275.642639  278.876683  273.064787  275.876989   7381943
# ..           ...         ...         ...         ...         ...       ...
# 270   2026-02-02  242.300003  244.080002  239.289993  244.000000  12335721
# 271   2026-02-03  242.690002  259.890015  242.279999  259.209991  25915412
# 272   2026-02-04  233.339996  235.919998  226.259995  235.910004  25995324
# 273   2026-02-05  233.389999  235.570007  231.699997  233.339996  10102736
# 274   2026-02-06  230.720001  232.929993  228.600006  232.929993  12279085
#
# Price  Stock
# 0      Wipro
# 1      Wipro
# 2      Wipro
# ...

# %%
hdfc = yf.download('HDFCBANK.NS',start = s,end = e)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
hdfc.columns = hdfc.columns.get_level_values(0)
hdfc = hdfc.reset_index()
hdfc['Stock'] = 'HDFC Bank Limited'

# %%
hdfc
# Out:
# Price       Date       Close        High         Low        Open    Volume  \
# 0     2025-01-01  879.487000  885.036981  868.806357  874.898991   7313806
# 1     2025-01-02  884.913635  889.698928  874.677004  876.699651  18558576
# 2     2025-01-03  862.935669  885.653615  861.505055  883.556955  24426194
# 3     2025-01-06  843.843750  866.882313  841.525115  858.446354  18816348
# 4     2025-01-07  845.274414  849.023722  838.663758  846.063733  13527906
# ..           ...         ...         ...         ...         ...       ...
# 270   2026-02-02  928.099976  929.799988  909.299988  915.000000  28032106
# 271   2026-02-03  948.700012  994.000000  945.000000  983.750000  50336968
# 272   2026-02-04  953.099976  957.200012  947.950012  952.500000  24366770
# 273   2026-02-05  949.700012  956.049988  946.700012  956.000000  28103169
# 274   2026-02-06  941.099976  948.099976  937.599976  945.000000  18120272
#
# Price              Stock
# 0      HDFC Bank Limited
# ...

# %%
maruti = yf.download('MARUTI.NS',start = s,end = e)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
maruti.columns = maruti.columns.get_level_values(0)
maruti = maruti.reset_index()
maruti['Stock'] = 'Maruti Suzuki India Ltd'

# %%
maruti
# Out:
# Price       Date         Close          High           Low          Open  \
# 0     2025-01-01  11088.287109  11153.234549  10684.557220  10741.738134
# 1     2025-01-02  11714.508789  11732.168239  11105.797323  11164.165579
# 2     2025-01-03  11806.463867  11920.776421  11661.730570  11723.066704
# 3     2025-01-06  11629.776367  11851.625203  11565.521628  11801.269830
# 4     2025-01-07  11595.793945  11699.323792  11548.704009  11629.776722
# ..           ...           ...           ...           ...           ...
# 270   2026-02-02  14384.000000  14446.000000  14058.000000  14251.000000
# 271   2026-02-03  14782.000000  15281.000000  14482.000000  15200.000000
# 272   2026-02-04  15071.000000  15170.000000  14723.000000  14800.000000
# 273   2026-02-05  15059.000000  15150.000000  14900.000000  15090.000000
# 274   2026-02-06  14997.000000  15118.000000  14871.000000  15084.000000
#
# Price   Volume                    Stock
# 0       383202  Maruti Suzuki India Ltd
# ...

# %%
hyundai = yf.download('HYUN.NS',start = s,end = e)
# Out:
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: HYUN.NS"}}}
# $HYUN.NS: possibly delisted; no timezone found
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['HYUN.NS']: possibly delisted; no timezone found

# %%
hyundai.columns = hyundai.columns.get_level_values(0)
hyundai = hyundai.reset_index()
hyundai['Stock'] = 'Hyundai Motor India Ltd'

# %%
hyundai
# Out:
# Empty DataFrame
# Columns: [Date, Adj Close, Close, High, Low, Open, Volume, Stock]
# Index: []

# %%
tata = yf.download('TMPV.NS',start = s,end = e)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tata.columns = tata.columns.get_level_values(0)
tata = tata.reset_index()
tata['Stock'] = 'Tata Motor Ltd'

# %%
tata
# Out:
# Price       Date       Close        High         Low        Open    Volume  \
# 0     2025-10-15  390.850006  403.000000  388.000000  403.000000  26953550
# 1     2025-10-16  396.799988  400.450012  389.549988  395.450012  21983750
# 2     2025-10-17  396.600006  402.500000  392.250000  396.799988  16564540
# 3     2025-10-20  399.750000  403.399994  396.600006  400.049988  10471670
# 4     2025-10-21  401.850006  403.399994  400.049988  402.799988   3449156
# ..           ...         ...         ...         ...         ...       ...
# 73    2026-02-02  362.899994  364.500000  341.100006  344.649994  19654610
# 74    2026-02-03  372.049988  384.600006  366.000000  381.149994  16720220
# 75    2026-02-04  375.450012  377.600006  368.450012  372.500000  10142350
# 76    2026-02-05  374.149994  375.600006  364.299988  375.000000  14013830
# 77    2026-02-06  369.500000  381.799988  361.000000  365.000000  23116970
#
# Price           Stock
# 0      Tata Motor Ltd
# ...

# %%
reliance = yf.download('RELIANCE.NS',start = s,end = e)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
reliance.columns = reliance.columns.get_level_values(0)
reliance = reliance.reset_index()
reliance['Stock'] = 'Reliance Industries Limited'

# %%
reliance
# Out:
# Price       Date        Close         High          Low         Open  \
# 0     2025-01-01  1216.391846  1221.421805  1206.780209  1210.017281
# 1     2025-01-02  1236.860107  1239.499468  1215.146780  1216.391808
# 2     2025-01-03  1246.172974  1257.029638  1230.585205  1238.951814
# 3     2025-01-06  1213.154785  1256.979753  1210.166719  1248.961727
# 4     2025-01-07  1235.913818  1239.549323  1216.391812  1217.138829
# ..           ...          ...          ...          ...          ...
# 270   2026-02-02  1390.400024  1392.900024  1335.500000  1340.000000
# 271   2026-02-03  1437.099976  1489.500000  1430.199951  1473.900024
# 272   2026-02-04  1456.800049  1464.000000  1440.300049  1444.000000
# 273   2026-02-05  1443.400024  1461.500000  1439.500000  1457.000000
# 274   2026-02-06  1450.800049  1452.800049  1433.500000  1441.500000
#
# Price    Volume                        Stock
# 0       5892590  Reliance Industries Limited
# 1      15486276  Reliance Industries Limited
# ...

# %%
tcs = yf.download('TCS.NS',start = s,end = e)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tcs.columns = tcs.columns.get_level_values(0)
tcs = tcs.reset_index()
tcs['Stock'] = 'Tata Consultancy Services Limited'

# %%
tcs
# Out:
# Price             Close         High          Low         Open    Volume
# Ticker           TCS.NS       TCS.NS       TCS.NS       TCS.NS    TCS.NS
# Date
# 2025-01-01  3903.252930  3923.706512  3877.626168  3886.120842    763161
# 2025-01-02  3963.332520  3970.213717  3888.541206  3910.418483   1720835
# 2025-01-03  3891.340576  3967.318761  3884.127322  3967.318761   1791953
# 2025-01-06  3886.690430  3938.560333  3859.545197  3896.656303   2085593
# 2025-01-07  3823.383301  3929.733444  3807.485361  3905.625616   2669054
# ...                 ...          ...          ...          ...       ...
# 2026-02-02  3169.600098  3198.000000  3134.000000  3198.000000   2636272
# 2026-02-03  3225.300049  3350.000000  3186.300049  3350.000000   4366060
# 2026-02-04  2999.100098  3120.000000  2986.000000  3120.000000  10852595
# 2026-02-05  2991.500000  3029.699951  2972.300049  2990.000000   3521545
# 2026-02-06  2941.600098  2985.000000  2916.000000  2976.600098   4687389
#
# ...

# %%
df = pd.concat([info,mah,sbi,wipro,hdfc,maruti,hyundai,tata,reliance,tcs] , axis=0)
df
# Out:
#                           Date        Close         High          Low  \
# 0                   2025-01-01  1828.390015  1838.539596  1820.134336
# 1                   2025-01-02  1901.574219  1906.236297  1831.109642
# 2                   2025-01-03  1883.023193  1896.814986  1866.754650
# 3                   2025-01-06  1882.149048  1916.288731  1872.582197
# 4                   2025-01-07  1875.350220  1902.254091  1868.357222
# ...                        ...          ...          ...          ...
# 2026-02-02 00:00:00        NaT          NaN          NaN          NaN
# 2026-02-03 00:00:00        NaT          NaN          NaN          NaN
# 2026-02-04 00:00:00        NaT          NaN          NaN          NaN
# 2026-02-05 00:00:00        NaT          NaN          NaN          NaN
# 2026-02-06 00:00:00        NaT          NaN          NaN          NaN
#
#                             Open     Volume    Stock  Adj Close  \
# ...

# %%
df.to_csv('Stock_I.csv')

# %%
df
# Out:
#                           Date        Close         High          Low  \
# 0                   2025-01-01  1828.390015  1838.539596  1820.134336
# 1                   2025-01-02  1901.574219  1906.236297  1831.109642
# 2                   2025-01-03  1883.023193  1896.814986  1866.754650
# 3                   2025-01-06  1882.149048  1916.288731  1872.582197
# 4                   2025-01-07  1875.350220  1902.254091  1868.357222
# ...                        ...          ...          ...          ...
# 2026-02-02 00:00:00        NaT          NaN          NaN          NaN
# 2026-02-03 00:00:00        NaT          NaN          NaN          NaN
# 2026-02-04 00:00:00        NaT          NaN          NaN          NaN
# 2026-02-05 00:00:00        NaT          NaN          NaN          NaN
# 2026-02-06 00:00:00        NaT          NaN          NaN          NaN
#
#                             Open     Volume    Stock  Adj Close  \
# ...

# %%
print(df.Stock.unique())
st = input("Enter Stock Name : ")
r = df[df.Stock == st]
# Out:
# ['Infosys' 'Mahindra & Mahindra Ltd' 'State Bank of India' 'Wipro'
#  'HDFC Bank Limited' 'Maruti Suzuki India Ltd' 'Tata Motor Ltd'
#  'Reliance Industries Limited' nan]
# Enter Stock Name :  Infosys

# %%
sb.lineplot(x = r.Date, y = r.Close)
plt.xticks(rotation = 90)
plt.show()

# %%
df.dtypes
# Out:
# Date                datetime64[ns]
# Close                      float64
# High                       float64
# Low                        float64
# Open                       float64
# Volume                     float64
# Stock                       object
# Adj Close                  float64
# (Close, TCS.NS)            float64
# (High, TCS.NS)             float64
# (Low, TCS.NS)              float64
# (Open, TCS.NS)             float64
# (Volume, TCS.NS)           float64
# dtype: object
